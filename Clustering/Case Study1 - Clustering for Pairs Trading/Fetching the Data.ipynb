# %% [markdown]
# ### Fetching the data for all the stocks of S&P500

# %%
import numpy as np
# Load libraries
import pandas as pd
import pandas_datareader as dr
import yfinance

# %%
# load dataset
#scraping wikipedia to fetch S&P 500 stock list
snp500url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
data_table = pd.read_html(snp500url)

tickers = data_table[0][1:]['Symbol'].tolist()
#print(tickers)
print("\nTotal number of companies are:", len(tickers))
raw_data = yfinance.download (tickers = 'AAPL', start = "2018-01-01",
                              end = "2019-01-01", interval = "1d")
DateColumn = np.array(raw_data.index)

DateColumn.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# Total number of companies are: 502
# (251,)

# %%
raw_data = yfinance.download (tickers = 'AAPL', start = "2018-01-01",
                              end = "2019-01-01", interval = "1d")
# Vérifiez les premières lignes des données pour comprendre leur structure

#raw_data.drop(['High', 'Low', 'Open', 'Volume'], axis=1, inplace=True)
prices = raw_data

print(raw_data['Close'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker           AAPL
# Date
# 2018-01-02  40.479836
# 2018-01-03  40.472782
# 2018-01-04  40.660774
# 2018-01-05  41.123711
# 2018-01-08  40.970978
# ...               ...
# 2018-12-24  35.021992
# 2018-12-26  37.488293
# 2018-12-27  37.244987
# 2018-12-28  37.264088
# 2018-12-31  37.624245
#
# [251 rows x 1 columns]

# %%
price_list = []
for ticker in tickers:
    raw_data = yfinance.download (tickers = ticker, start = "2018-01-01",
                                      end = "2019-09-01", interval = "1d")
    try:
        prices = raw_data['Close']
        #print(prices)
        prices = pd.DataFrame(prices)
        prices.columns = [ticker]
        price_list.append(prices)
    except:
        pass
    prices_df = pd.concat(price_list,axis=1)
prices_df.sort_index(inplace=True)
#Once the data is downloaded the data is saved to csv and the data is pulled from the csv
prices_df.to_csv("SP500Data.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABNB']: YFPricesMissingError('possibly delisted; no price data found  (1d 2018-01-01 -> 2019-09-01) (Yahoo error = "Data doesn\'t exist for startDate = 1514782800, endDate = 1567310400")')
# ...
